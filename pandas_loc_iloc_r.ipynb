# %% [markdown]
# <font size='6' color='blue'>
# Pandas
# <i>loc and iloc </i>  <br>
# </font>

# %% [markdown]
# <font size='4' color='blue' >
#
# loc  - label-based  <br>
# iloc - position-based (integer position values) <br>
#
# </font>

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = sns.load_dataset('tips')
#sns.get_dataset_names()
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
col = [i for i in range(len(df.columns))]
df.columns = col
df
# Out:
#          0     1       2    3     4       5  6
# 0    16.99  1.01  Female   No   Sun  Dinner  2
# 1    10.34  1.66    Male   No   Sun  Dinner  3
# 2    21.01  3.50    Male   No   Sun  Dinner  3
# 3    23.68  3.31    Male   No   Sun  Dinner  2
# 4    24.59  3.61  Female   No   Sun  Dinner  4
# ..     ...   ...     ...  ...   ...     ... ..
# 239  29.03  5.92    Male   No   Sat  Dinner  3
# 240  27.18  2.00  Female  Yes   Sat  Dinner  2
# 241  22.67  2.00    Male  Yes   Sat  Dinner  2
# 242  17.82  1.75    Male   No   Sat  Dinner  2
# 243  18.78  3.00  Female   No  Thur  Dinner  2
#
# [244 rows x 7 columns]

# %% [markdown]
# **Specific records/rows**

# %%
df.loc[3]  #  shows a series, a 1-dimensional data
# Out:
# 0     23.68
# 1      3.31
# 2      Male
# 3        No
# 4       Sun
# 5    Dinner
# 6         2
# Name: 3, dtype: object

# %%
df.loc[[3]]  # work around to get a tablu
# Out:
#        0     1     2   3    4       5  6
# 3  23.68  3.31  Male  No  Sun  Dinner  2

# %%
df.iloc[[3]]
# Out:
#        0     1     2   3    4       5  6
# 3  23.68  3.31  Male  No  Sun  Dinner  2

# %%
df.loc[[3,4]]
# Out:
#        0     1       2   3    4       5  6
# 3  23.68  3.31    Male  No  Sun  Dinner  2
# 4  24.59  3.61  Female  No  Sun  Dinner  4

# %%
df.iloc[[3,4]]
# Out:
#        0     1       2   3    4       5  6
# 3  23.68  3.31    Male  No  Sun  Dinner  2
# 4  24.59  3.61  Female  No  Sun  Dinner  4

# %% [markdown]
# **Slicing**
#
# loc  = [ from_number : to_number ]   - both inclusive <br>
# iloc = [ from_number : to_number ]   - from_number inclusive, to_number exclusive

# %%
df
# Out:
#          0     1       2    3     4       5  6
# 0    16.99  1.01  Female   No   Sun  Dinner  2
# 1    10.34  1.66    Male   No   Sun  Dinner  3
# 2    21.01  3.50    Male   No   Sun  Dinner  3
# 3    23.68  3.31    Male   No   Sun  Dinner  2
# 4    24.59  3.61  Female   No   Sun  Dinner  4
# ..     ...   ...     ...  ...   ...     ... ..
# 239  29.03  5.92    Male   No   Sat  Dinner  3
# 240  27.18  2.00  Female  Yes   Sat  Dinner  2
# 241  22.67  2.00    Male  Yes   Sat  Dinner  2
# 242  17.82  1.75    Male   No   Sat  Dinner  2
# 243  18.78  3.00  Female   No  Thur  Dinner  2
#
# [244 rows x 7 columns]

# %%
df.loc[1:4]
# Out:
#        0     1       2   3    4       5  6
# 1  10.34  1.66    Male  No  Sun  Dinner  3
# 2  21.01  3.50    Male  No  Sun  Dinner  3
# 3  23.68  3.31    Male  No  Sun  Dinner  2
# 4  24.59  3.61  Female  No  Sun  Dinner  4

# %%
df.iloc[1:4+1]     # to_number is exclusive, make it 5 to include 4
# Out:
#        0     1       2   3    4       5  6
# 1  10.34  1.66    Male  No  Sun  Dinner  3
# 2  21.01  3.50    Male  No  Sun  Dinner  3
# 3  23.68  3.31    Male  No  Sun  Dinner  2
# 4  24.59  3.61  Female  No  Sun  Dinner  4

# %%
df.loc[2: :3]    # with step 2, alternative rows     ## 1, 2, 3, 4
# Out:
#          0      1       2    3     4       5  6
# 2    21.01   3.50    Male   No   Sun  Dinner  3
# 5    25.29   4.71    Male   No   Sun  Dinner  4
# 8    15.04   1.96    Male   No   Sun  Dinner  2
# 11   35.26   5.00  Female   No   Sun  Dinner  4
# 14   14.83   3.02  Female   No   Sun  Dinner  2
# 17   16.29   3.71    Male   No   Sun  Dinner  3
# 20   17.92   4.08    Male   No   Sat  Dinner  2
# 23   39.42   7.58    Male   No   Sat  Dinner  4
# 26   13.37   2.00    Male   No   Sat  Dinner  2
# 29   19.65   3.00  Female   No   Sat  Dinner  2
# 32   15.06   3.00  Female   No   Sat  Dinner  2
# 35   24.06   3.60    Male   No   Sat  Dinner  3
# 38   18.69   2.31    Male   No   Sat  Dinner  3
# 41   17.46   2.54    Male   No   Sun  Dinner  2
# 44   30.40   5.60    Male   No   Sun  Dinner  4
# 47   32.40   6.00    Male   No   Sun  Dinner  4
# 50   12.54   2.50    Male   No   Sun  Dinner  2
# 53    9.94   1.56    Male   No   Sun  Dinner  2
# 56   38.01   3.00    Male  Yes   Sat  Dinner  4
# ...

# %%
df.iloc[2::3]    # 1, 2, 3
# Out:
#          0      1       2    3     4       5  6
# 2    21.01   3.50    Male   No   Sun  Dinner  3
# 5    25.29   4.71    Male   No   Sun  Dinner  4
# 8    15.04   1.96    Male   No   Sun  Dinner  2
# 11   35.26   5.00  Female   No   Sun  Dinner  4
# 14   14.83   3.02  Female   No   Sun  Dinner  2
# 17   16.29   3.71    Male   No   Sun  Dinner  3
# 20   17.92   4.08    Male   No   Sat  Dinner  2
# 23   39.42   7.58    Male   No   Sat  Dinner  4
# 26   13.37   2.00    Male   No   Sat  Dinner  2
# 29   19.65   3.00  Female   No   Sat  Dinner  2
# 32   15.06   3.00  Female   No   Sat  Dinner  2
# 35   24.06   3.60    Male   No   Sat  Dinner  3
# 38   18.69   2.31    Male   No   Sat  Dinner  3
# 41   17.46   2.54    Male   No   Sun  Dinner  2
# 44   30.40   5.60    Male   No   Sun  Dinner  4
# 47   32.40   6.00    Male   No   Sun  Dinner  4
# 50   12.54   2.50    Male   No   Sun  Dinner  2
# 53    9.94   1.56    Male   No   Sun  Dinner  2
# 56   38.01   3.00    Male  Yes   Sat  Dinner  4
# ...

# %%
df.head(3)
# Out:
#        0     1       2   3    4       5  6
# 0  16.99  1.01  Female  No  Sun  Dinner  2
# 1  10.34  1.66    Male  No  Sun  Dinner  3
# 2  21.01  3.50    Male  No  Sun  Dinner  3

# %%
df.loc[[0,2], [3,4]]
# Out:
#     3    4
# 0  No  Sun
# 2  No  Sun

# %%
df.iloc[[0,2], [3,4]]
# Out:
#     3    4
# 0  No  Sun
# 2  No  Sun

# %%
df.loc[2:10, :]                         # [      from_row     :  to_row   , from_col    :  to_col       ]
# Out:
#         0     1       2   3    4       5  6
# 2   21.01  3.50    Male  No  Sun  Dinner  3
# 3   23.68  3.31    Male  No  Sun  Dinner  2
# 4   24.59  3.61  Female  No  Sun  Dinner  4
# 5   25.29  4.71    Male  No  Sun  Dinner  4
# 6    8.77  2.00    Male  No  Sun  Dinner  2
# 7   26.88  3.12    Male  No  Sun  Dinner  4
# 8   15.04  1.96    Male  No  Sun  Dinner  2
# 9   14.78  3.23    Male  No  Sun  Dinner  2
# 10  10.27  1.71    Male  No  Sun  Dinner  2

# %%
df.iloc[2:10+1, :]
# Out:
#         0     1       2   3    4       5  6
# 2   21.01  3.50    Male  No  Sun  Dinner  3
# 3   23.68  3.31    Male  No  Sun  Dinner  2
# 4   24.59  3.61  Female  No  Sun  Dinner  4
# 5   25.29  4.71    Male  No  Sun  Dinner  4
# 6    8.77  2.00    Male  No  Sun  Dinner  2
# 7   26.88  3.12    Male  No  Sun  Dinner  4
# 8   15.04  1.96    Male  No  Sun  Dinner  2
# 9   14.78  3.23    Male  No  Sun  Dinner  2
# 10  10.27  1.71    Male  No  Sun  Dinner  2

# %%
df.loc[ : , 2:4 ]
# Out:
#           2    3     4
# 0    Female   No   Sun
# 1      Male   No   Sun
# 2      Male   No   Sun
# 3      Male   No   Sun
# 4    Female   No   Sun
# ..      ...  ...   ...
# 239    Male   No   Sat
# 240  Female  Yes   Sat
# 241    Male  Yes   Sat
# 242    Male   No   Sat
# 243  Female   No  Thur
#
# [244 rows x 3 columns]

# %%
df.iloc[: ,2:4+1]
# Out:
#           2    3     4
# 0    Female   No   Sun
# 1      Male   No   Sun
# 2      Male   No   Sun
# 3      Male   No   Sun
# 4    Female   No   Sun
# ..      ...  ...   ...
# 239    Male   No   Sat
# 240  Female  Yes   Sat
# 241    Male  Yes   Sat
# 242    Male   No   Sat
# 243  Female   No  Thur
#
# [244 rows x 3 columns]

# %%
##Let us have labeled-based rows and columns

# %%
df = sns.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.index = ['row'+str(i) for i in range(1, len(df)+1) ]
df.head(10)
# Out:
#        total_bill   tip     sex smoker  day    time  size
# row1        16.99  1.01  Female     No  Sun  Dinner     2
# row2        10.34  1.66    Male     No  Sun  Dinner     3
# row3        21.01  3.50    Male     No  Sun  Dinner     3
# row4        23.68  3.31    Male     No  Sun  Dinner     2
# row5        24.59  3.61  Female     No  Sun  Dinner     4
# row6        25.29  4.71    Male     No  Sun  Dinner     4
# row7         8.77  2.00    Male     No  Sun  Dinner     2
# row8        26.88  3.12    Male     No  Sun  Dinner     4
# row9        15.04  1.96    Male     No  Sun  Dinner     2
# row10       14.78  3.23    Male     No  Sun  Dinner     2

# %%
df.loc['row1', 'total_bill']
# Out:
# 16.99

# %%
df.loc['row1' : 'row10', 'tip' : 'time']
# Out:
#         tip     sex smoker  day    time
# row1   1.01  Female     No  Sun  Dinner
# row2   1.66    Male     No  Sun  Dinner
# row3   3.50    Male     No  Sun  Dinner
# row4   3.31    Male     No  Sun  Dinner
# row5   3.61  Female     No  Sun  Dinner
# row6   4.71    Male     No  Sun  Dinner
# row7   2.00    Male     No  Sun  Dinner
# row8   3.12    Male     No  Sun  Dinner
# row9   1.96    Male     No  Sun  Dinner
# row10  3.23    Male     No  Sun  Dinner

# %%
df.iloc[0:9+1, 1:6]
# Out:
#         tip     sex smoker  day    time
# row1   1.01  Female     No  Sun  Dinner
# row2   1.66    Male     No  Sun  Dinner
# row3   3.50    Male     No  Sun  Dinner
# row4   3.31    Male     No  Sun  Dinner
# row5   3.61  Female     No  Sun  Dinner
# row6   4.71    Male     No  Sun  Dinner
# row7   2.00    Male     No  Sun  Dinner
# row8   3.12    Male     No  Sun  Dinner
# row9   1.96    Male     No  Sun  Dinner
# row10  3.23    Male     No  Sun  Dinner
